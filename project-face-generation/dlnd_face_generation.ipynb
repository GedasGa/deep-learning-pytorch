# %% [markdown]
# # Face Generation
#
# In this project, you'll define and train a DCGAN on a dataset of faces. Your goal is to get a generator network to generate *new* images of faces that look as realistic as possible!
#
# The project will be broken down into a series of tasks from **loading in data to defining and training adversarial networks**. At the end of the notebook, you'll be able to visualize the results of your trained Generator to see how it performs; your generated samples should look like fairly realistic faces with small amounts of noise.
#
# ### Get the Data
#
# You'll be using the [CelebFaces Attributes Dataset (CelebA)](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) to train your adversarial networks.
#
# This dataset is more complex than the number datasets (like MNIST or SVHN) you've been working with, and so, you should prepare to define deeper networks and train them for a longer time to get good results. It is suggested that you utilize a GPU for training.
#
# ### Pre-processed Data
#
# Since the project's main focus is on building the GANs, we've done *some* of the pre-processing for you. Each of the CelebA images has been cropped to remove parts of the image that don't include a face, then resized down to 64x64x3 NumPy images. Some sample data is show below.
#
# <img src='assets/processed_face_data.png' width=60% />
#
# > If you are working locally, you can download this data [by clicking here](https://s3.amazonaws.com/video.udacity-data.com/topher/2018/November/5be7eb6f_processed-celeba-small/processed-celeba-small.zip)
#
# This is a zip file that you'll need to extract in the home directory of this notebook for further loading and processing. After extracting the data, you should be left with a directory of data `processed_celeba_small/`

# %%
# can comment out after executing
# !unzip processed_celeba_small.zip
# Out:
# Archive:  processed_celeba_small.zip
# replace processed_celeba_small/.DS_Store? [y]es, [n]o, [A]ll, [N]one, [r]ename: ^C

# %%
data_dir = 'processed_celeba_small/'

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle as pkl
import matplotlib.pyplot as plt
import numpy as np
import problem_unittests as tests
#import helper

# %matplotlib inline

# %% [markdown]
# ## Visualize the CelebA Data
#
# The [CelebA](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) dataset contains over 200,000 celebrity images with annotations. Since you're going to be generating faces, you won't need the annotations, you'll only need the images. Note that these are color images with [3 color channels (RGB)](https://en.wikipedia.org/wiki/Channel_(digital_image)#RGB_Images) each.
#
# ### Pre-process and Load the Data
#
# Since the project's main focus is on building the GANs, we've done *some* of the pre-processing for you. Each of the CelebA images has been cropped to remove parts of the image that don't include a face, then resized down to 64x64x3 NumPy images. This *pre-processed* dataset is a smaller subset of the very large CelebA data.
#
# > There are a few other steps that you'll need to **transform** this data and create a **DataLoader**.
#
# #### Exercise: Complete the following `get_dataloader` function, such that it satisfies these requirements:
#
# * Your images should be square, Tensor images of size `image_size x image_size` in the x and y dimension.
# * Your function should return a DataLoader that shuffles and batches these Tensor images.
#
# #### ImageFolder
#
# To create a dataset given a directory of images, it's recommended that you use PyTorch's [ImageFolder](https://pytorch.org/docs/stable/torchvision/datasets.html#imagefolder) wrapper, with a root directory `processed_celeba_small/` and data transformation passed in.

# %%
# necessary imports
import torch
from torchvision import datasets
from torchvision import transforms
from torch.utils.data import DataLoader

# %%
def get_dataloader(batch_size, image_size, data_dir='processed_celeba_small/'):
    """
    Batch the neural network data using DataLoader
    :param batch_size: The size of each batch; the number of images in a batch
    :param img_size: The square size of the image data (x, y)
    :param data_dir: Directory where image data is located
    :return: DataLoader with batched data
    """
    
    # resize and normalize the images
    transform = transforms.Compose([transforms.Resize(image_size), # resize to image_size x image_size
                                    transforms.ToTensor()])

    # define image dataset using ImageFolder
    image_dataset = datasets.ImageFolder(data_dir, transform=transform)

    # create and return DataLoader
    data_loader = DataLoader(dataset=image_dataset, batch_size=batch_size, shuffle=True)
    
    return data_loader

# %% [markdown]
# ## Create a DataLoader
#
# #### Exercise: Create a DataLoader `celeba_train_loader` with appropriate hyperparameters.
#
# Call the above function and create a dataloader to view images.
# * You can decide on any reasonable `batch_size` parameter
# * Your `image_size` **must be** `32`. Resizing the data to a smaller size will make for faster training, while still creating convincing images of faces!

# %%
# Define function hyperparameters
batch_size = 128
img_size = 32

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# Call your function and get a dataloader
celeba_train_loader = get_dataloader(batch_size, img_size)

# %% [markdown]
# Next, you can view some images! You should seen square images of somewhat-centered faces.
#
# Note: You'll need to convert the Tensor images into a NumPy type and transpose the dimensions to correctly display an image, suggested `imshow` code is below, but it may not be perfect.

# %%
# Helper display function
def imshow(img):
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# obtain one batch of training images
dataiter = iter(celeba_train_loader)
images, _ = dataiter.next() # _ for no labels

# plot the images in the batch, along with the corresponding labels
fig = plt.figure(figsize=(20, 4))
plot_size=20
for idx in np.arange(plot_size):
    ax = fig.add_subplot(2, plot_size/2, idx+1, xticks=[], yticks=[])
    imshow(images[idx])

# %% [markdown]
# #### Exercise: Pre-process your image data and scale it to a pixel range of -1 to 1
#
# You need to do a bit of pre-processing; you know that the output of a `tanh` activated generator will contain pixel values in a range from -1 to 1, and so, we need to rescale our training images to a range of -1 to 1. (Right now, they are in a range from 0-1.)

# %%
# Helper scale function
def scale(x, feature_range=(-1, 1)):
    ''' Scale takes in an image x and returns that image, scaled
       with a feature_range of pixel values from -1 to 1. 
       This function assumes that the input x is already scaled from 0-1.'''
    # assume x is scaled to (0, 1)
    # scale to feature_range and return scaled x
    min, max = feature_range
    x = x * (max - min) + min
    
    return x

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# check scaled range
# should be close to -1 to 1
img = images[0]
scaled_img = scale(img)

print('Min: ', scaled_img.min())
print('Max: ', scaled_img.max())
# Out:
# Min:  tensor(-0.9843)
# Max:  tensor(0.8588)

# %% [markdown]
# ---
# # Define the Model
#
# A GAN is comprised of two adversarial networks, a discriminator and a generator.
#
# ## Discriminator
#
# Your first task will be to define the discriminator. This is a convolutional classifier like you've built before, only without any maxpooling layers. To deal with this complex data, it's suggested you use a deep network with **normalization**. You are also allowed to create any helper functions that may be useful.
#
# #### Exercise: Complete the Discriminator class
# * The inputs to the discriminator are 32x32x3 tensor images
# * The output should be a single value that will indicate whether a given image is real or fake

# %%
import torch.nn as nn
import torch.nn.functional as F

# Helper conv function
def conv(in_channels, out_channels, kernel_size, stride=2, padding=1, batch_norm=True):
    """Creates a convolutional layer, with optional batch normalization.
    """
    layers = []
    conv_layer = nn.Conv2d(in_channels, out_channels, 
                           kernel_size, stride, padding, bias=False)
    
    # append conv layer
    layers.append(conv_layer)

    if batch_norm:
        # append batchnorm layer
        layers.append(nn.BatchNorm2d(out_channels))
     
    # using Sequential container
    return nn.Sequential(*layers)

# %%
class Discriminator(nn.Module):

    def __init__(self, conv_dim):
        """
        Initialize the Discriminator Module
        :param conv_dim: The depth of the first convolutional layer
        """
        super(Discriminator, self).__init__()
        
        # assign parameter to the class scope, 
        # so it could be used in foward function
        self.conv_dim = conv_dim

        # define convolutional layers
        self.conv1 = conv(3, conv_dim, 4, batch_norm=False)
        self.conv2 = conv(conv_dim, conv_dim*2, 4)
        self.conv3 = conv(conv_dim*2, conv_dim*4, 4)
        self.conv4 = conv(conv_dim*4, conv_dim*8, 4)
        
        # define final fully-connected layer
        self.fc = nn.Linear(conv_dim*32, 1)

    def forward(self, x):
        """
        Forward propagation of the neural network
        :param x: The input to the neural network     
        :return: Discriminator logits; the output of the neural network
        """
        # apply conv layers with leaky relu activation
        x = F.leaky_relu(self.conv1(x), 0.2)
        x = F.leaky_relu(self.conv2(x), 0.2)
        x = F.leaky_relu(self.conv3(x), 0.2)
        x = F.leaky_relu(self.conv4(x), 0.2)
        
        # flatten
        x = x.view(-1, self.conv_dim*32)
        
        # final fully-connected layer
        x = self.fc(x)
        
        return x


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_discriminator(Discriminator)
# Out:
# Tests Passed

# %% [markdown]
# ## Generator
#
# The generator should upsample an input and generate a *new* image of the same size as our training data `32x32x3`. This should be mostly transpose convolutional layers with normalization applied to the outputs.
#
# #### Exercise: Complete the Generator class
# * The inputs to the generator are vectors of some length `z_size`
# * The output should be a image of shape `32x32x3`

# %%
# Helper deconv function
def deconv(in_channels, out_channels, kernel_size, stride=2, padding=1, batch_norm=True):
    """Creates a transposed-convolutional layer, with optional batch normalization.
    """
    ## create a sequence of transpose + optional batch norm layers
    layers = []
    transpose_conv_layer = nn.ConvTranspose2d(in_channels, out_channels, 
                                    kernel_size, stride, padding, bias=False)
    
    # append transpose conv layer
    layers.append(transpose_conv_layer)

    if batch_norm:
        # append batchnorm layer
        layers.append(nn.BatchNorm2d(out_channels))
     
    # using Sequential container
    return nn.Sequential(*layers)

# %%
class Generator(nn.Module):
    
    def __init__(self, z_size, conv_dim):
        """
        Initialize the Generator Module
        :param z_size: The length of the input latent vector, z
        :param conv_dim: The depth of the inputs to the *last* transpose convolutional layer
        """
        super(Generator, self).__init__()
        
        # assign parameter to the class scope, 
        # so it could be used in foward function
        self.conv_dim = conv_dim
        
        # define fully-connected layer
        self.fc = nn.Linear(z_size, conv_dim*32)
        
        # define transpose convolutional layers
        self.tconv1 = deconv(conv_dim*8, conv_dim*4, 4)
        self.tconv2 = deconv(conv_dim*4, conv_dim*2, 4)
        self.tconv3 = deconv(conv_dim*2, conv_dim, 4)
        self.tconv4 = deconv(conv_dim, 3, 4, batch_norm=False)

    def forward(self, x):
        """
        Forward propagation of the neural network
        :param x: The input to the neural network     
        :return: A 32x32x3 Tensor image as output
        """
        # final fully-connected layer
        x = self.fc(x)
        
        # reshape
        x = x.view(-1, self.conv_dim*8, 2, 2)
        
        # apply transpose conv layers with relu activation
        x = F.relu(self.tconv1(x))
        x = F.relu(self.tconv2(x))
        x = F.relu(self.tconv3(x))
        
        # apply last transpose conv layers
        x = self.tconv4(x)
        
        # apply tanh activation
        x = F.tanh(x)
        
        return x

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_generator(Generator)
# Out:
# Tests Passed

# %% [markdown]
# ## Initialize the weights of your networks
#
# To help your models converge, you should initialize the weights of the convolutional and linear layers in your model. From reading the [original DCGAN paper](https://arxiv.org/pdf/1511.06434.pdf), they say:
# > All weights were initialized from a zero-centered Normal distribution with standard deviation 0.02.
#
# So, your next task will be to define a weight initialization function that does just this!
#
# You can refer back to the lesson on weight initialization or even consult existing model code, such as that from [the `networks.py` file in CycleGAN Github repository](https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix/blob/master/models/networks.py) to help you complete this function.
#
# #### Exercise: Complete the weight initialization function
#
# * This should initialize only **convolutional** and **linear** layers
# * Initialize the weights to a normal distribution, centered around 0, with a standard deviation of 0.02.
# * The bias terms, if they exist, may be left alone or set to 0.

# %%
def weights_init_normal(m):
    """
    Applies initial weights to certain layers in a model.
    The weights are taken from a normal distribution 
    with mean = 0, std dev = 0.02.
    :param m: A module or layer in a network    
    """
    # classname will be something like:
    # `Conv`, `BatchNorm2d`, `Linear`, etc.
    classname = m.__class__.__name__
    
    # Apply initial weights to convolutional and linear layers
    if hasattr(m, 'weight') and (classname.find('Conv') != -1 or classname.find('Linear') != -1):
        nn.init.normal_(m.weight.data, mean=0.0, std=0.02)
        
        if hasattr(m, 'bias') and m.bias is not None:
            nn.init.constant_(m.bias.data, 0.0)

# %% [markdown]
# ## Build complete network
#
# Define your models' hyperparameters and instantiate the discriminator and generator from the classes defined above. Make sure you've passed in the correct input arguments.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
def build_network(d_conv_dim, g_conv_dim, z_size):
    # define discriminator and generator
    D = Discriminator(d_conv_dim)
    G = Generator(z_size=z_size, conv_dim=g_conv_dim)

    # initialize model weights
    D.apply(weights_init_normal)
    G.apply(weights_init_normal)

    print(D)
    print()
    print(G)
    
    return D, G

# %% [markdown]
# #### Exercise: Define model hyperparameters

# %%
# Define model hyperparams
d_conv_dim = 32
g_conv_dim = 32
z_size = 128

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
D, G = build_network(d_conv_dim, g_conv_dim, z_size)
# Out:
# Discriminator(
#   (conv1): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv4): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (fc): Linear(in_features=1024, out_features=1, bias=True)
# )
#
# Generator(
#   (fc): Linear(in_features=128, out_features=1024, bias=True)
#   (tconv1): Sequential(
#     (0): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (tconv2): Sequential(
#     (0): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (tconv3): Sequential(
#     (0): ConvTranspose2d(64, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (tconv4): Sequential(
#     (0): ConvTranspose2d(32, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
# )

# %% [markdown]
# ### Training on GPU
#
# Check if you can train on GPU. Here, we'll set this as a boolean variable `train_on_gpu`. Later, you'll be responsible for making sure that
# >* Models,
# * Model inputs, and
# * Loss function arguments
#
# Are moved to GPU, where appropriate.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import torch

# Check for a GPU
train_on_gpu = torch.cuda.is_available()
if not train_on_gpu:
    print('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Training on GPU!')
# Out:
# Training on GPU!

# %% [markdown]
# ---
# ## Discriminator and Generator Losses
#
# Now we need to calculate the losses for both types of adversarial networks.
#
# ### Discriminator Losses
#
# > * For the discriminator, the total loss is the sum of the losses for real and fake images, `d_loss = d_real_loss + d_fake_loss`.
# * Remember that we want the discriminator to output 1 for real images and 0 for fake images, so we need to set up the losses to reflect that.
#
#
# ### Generator Loss
#
# The generator loss will look similar only with flipped labels. The generator's goal is to get the discriminator to *think* its generated images are *real*.
#
# #### Exercise: Complete real and fake loss functions
#
# **You may choose to use either cross entropy or a least squares error loss to complete the following `real_loss` and `fake_loss` functions.**

# %%
def real_loss(D_out):
    '''Calculates how close discriminator outputs are to being real.
       param, D_out: discriminator logits
       return: real loss'''
    batch_size = D_out.size(0)
    # smooth, real labels = 0.9
    labels = torch.ones(batch_size)*0.9
    # move labels to GPU if available     
    if train_on_gpu:
        labels = labels.cuda()
        
    # binary cross entropy with logits loss
    criterion = nn.BCEWithLogitsLoss()
    # calculate loss
    loss = criterion(D_out.squeeze(), labels)
    
    return loss

def fake_loss(D_out):
    '''Calculates how close discriminator outputs are to being fake.
       param, D_out: discriminator logits
       return: fake loss'''
    batch_size = D_out.size(0)
    # fake labels = 0
    labels = torch.zeros(batch_size)
    # move labels to GPU if available   
    if train_on_gpu:
        labels = labels.cuda()
        
    # binary cross entropy with logits loss
    criterion = nn.BCEWithLogitsLoss()
    # calculate loss
    loss = criterion(D_out.squeeze(), labels)
    
    return loss

# %% [markdown]
# ## Optimizers
#
# #### Exercise: Define optimizers for your Discriminator (D) and Generator (G)
#
# Define optimizers for your models with appropriate hyperparameters.

# %%
import torch.optim as optim

# Create optimizers for the discriminator D and generator G
d_optimizer = optim.Adam(D.parameters(), lr=0.0002, betas=(0.5, 0.999))
g_optimizer = optim.Adam(G.parameters(), lr=0.0002, betas=(0.5, 0.999))

# %% [markdown]
# ---
# ## Training
#
# Training will involve alternating between training the discriminator and the generator. You'll use your functions `real_loss` and `fake_loss` to help you calculate the discriminator losses.
#
# * You should train the discriminator by alternating on real and fake images
# * Then the generator, which tries to trick the discriminator and should have an opposing loss function
#
#
# #### Saving Samples
#
# You've been given some code to print out some loss statistics and save some generated "fake" samples.

# %% [markdown]
# #### Exercise: Complete the training function
#
# Keep in mind that, if you've moved your models to GPU, you'll also have to move any model inputs to GPU.

# %%
def train(D, G, n_epochs, print_every=50):
    '''Trains adversarial networks for some number of epochs
       param, D: the discriminator network
       param, G: the generator network
       param, n_epochs: number of epochs to train for
       param, print_every: when to print and record the models' losses
       return: D and G losses'''
    
    # move models to GPU
    if train_on_gpu:
        D.cuda()
        G.cuda()

    # keep track of loss and generated, "fake" samples
    samples = []
    losses = []

    # Get some fixed data for sampling. These are images that are held
    # constant throughout training, and allow us to inspect the model's performance
    sample_size=16
    fixed_z = np.random.uniform(-1, 1, size=(sample_size, z_size))
    fixed_z = torch.from_numpy(fixed_z).float()
    # move z to GPU if available
    if train_on_gpu:
        fixed_z = fixed_z.cuda()

    # epoch training loop
    for epoch in range(n_epochs):

        # batch training loop
        for batch_i, (real_images, _) in enumerate(celeba_train_loader):

            batch_size = real_images.size(0)
            real_images = scale(real_images)

            # ===============================================
            #         YOUR CODE HERE: TRAIN THE NETWORKS
            # ===============================================
            
            # 1. Train the discriminator on real and fake images
            
            d_optimizer.zero_grad()
            
            # Move z to GPU if available
            if train_on_gpu:
                real_images = real_images.cuda()
            # Compute the discriminator losses on real images 
            D_real = D(real_images)
            d_real_loss = real_loss(D_real)
            
            # Generate fake images
            z = np.random.uniform(-1, 1, size=(batch_size, z_size))
            z = torch.from_numpy(z).float()
            
            # Move z to GPU if available
            if train_on_gpu:
                z = z.cuda()
            fake_images = G(z)

            # Compute the discriminator losses on fake images            
            D_fake = D(fake_images)
            d_fake_loss = fake_loss(D_fake)

            # Add up loss and perform backprop
            d_loss = d_real_loss + d_fake_loss
            d_loss.backward()
            d_optimizer.step()

            # 2. Train the generator with an adversarial loss
            
            g_optimizer.zero_grad()
            
            # Generate fake images
            z = np.random.uniform(-1, 1, size=(batch_size, z_size))
            z = torch.from_numpy(z).float()
            
            # Move z to GPU if available
            if train_on_gpu:
                z = z.cuda()

            # Compute the discriminator losses on fake images 
            # using flipped labels!
            fake_images = G(z)
            D_fake = D(fake_images)
            
            # Use real loss to flip labels and perform backprop
            g_loss = real_loss(D_fake)
            g_loss.backward()
            g_optimizer.step()
            
            
            # ===============================================
            #              END OF YOUR CODE
            # ===============================================

            # Print some loss stats
            if batch_i % print_every == 0:
                # append discriminator loss and generator loss
                losses.append((d_loss.item(), g_loss.item()))
                # print discriminator and generator loss
                print('Epoch [{:5d}/{:5d}] | d_loss: {:6.4f} | g_loss: {:6.4f}'.format(
                        epoch+1, n_epochs, d_loss.item(), g_loss.item()))


        ## AFTER EACH EPOCH##    
        # this code assumes your generator is named G, feel free to change the name
        # generate and save sample, fake images
        G.eval() # for generating samples
        samples_z = G(fixed_z)
        samples.append(samples_z)
        G.train() # back to training mode

    # Save training generator samples
    with open('train_samples.pkl', 'wb') as f:
        pkl.dump(samples, f)
    
    # finally return losses
    return losses

# %% [markdown]
# Set your number of training epochs and train your GAN!

# %%
# set number of epochs 
n_epochs = 30


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# call training function
losses = train(D, G, n_epochs=n_epochs)
# Out:
# Epoch [    1/   30] | d_loss: 1.4002 | g_loss: 0.8580
# Epoch [    1/   30] | d_loss: 0.4227 | g_loss: 3.6472
# Epoch [    1/   30] | d_loss: 0.3948 | g_loss: 3.0872
# Epoch [    1/   30] | d_loss: 0.4236 | g_loss: 2.9540
# Epoch [    1/   30] | d_loss: 0.7088 | g_loss: 3.0591
# Epoch [    1/   30] | d_loss: 0.5321 | g_loss: 2.3642
# Epoch [    1/   30] | d_loss: 0.9180 | g_loss: 2.2528
# Epoch [    1/   30] | d_loss: 0.5275 | g_loss: 2.2344
# Epoch [    1/   30] | d_loss: 0.6863 | g_loss: 2.1865
# Epoch [    1/   30] | d_loss: 0.7411 | g_loss: 2.8022
# Epoch [    1/   30] | d_loss: 1.5296 | g_loss: 1.0889
# Epoch [    1/   30] | d_loss: 1.1527 | g_loss: 1.6857
# Epoch [    1/   30] | d_loss: 1.0293 | g_loss: 2.3769
# Epoch [    1/   30] | d_loss: 0.8602 | g_loss: 1.4855
# Epoch [    1/   30] | d_loss: 0.8502 | g_loss: 1.8246
# Epoch [    2/   30] | d_loss: 0.7622 | g_loss: 1.8702
# Epoch [    2/   30] | d_loss: 0.9028 | g_loss: 1.6157
# Epoch [    2/   30] | d_loss: 0.8960 | g_loss: 2.0561
# Epoch [    2/   30] | d_loss: 1.2149 | g_loss: 1.6110
# Epoch [    2/   30] | d_loss: 0.9552 | g_loss: 2.0022
# Epoch [    2/   30] | d_loss: 0.8773 | g_loss: 1.5077
# Epoch [    2/   30] | d_loss: 0.8405 | g_loss: 1.6362
# Epoch [    2/   30] | d_loss: 0.9807 | g_loss: 1.9874
# Epoch [    2/   30] | d_loss: 0.9368 | g_loss: 1.4814
# Epoch [    2/   30] | d_loss: 1.0625 | g_loss: 1.5826
# Epoch [    2/   30] | d_loss: 0.9639 | g_loss: 2.2525
# Epoch [    2/   30] | d_loss: 0.8410 | g_loss: 2.2652
# Epoch [    2/   30] | d_loss: 0.8526 | g_loss: 1.6352
# Epoch [    2/   30] | d_loss: 0.9660 | g_loss: 1.1503
# Epoch [    2/   30] | d_loss: 0.7598 | g_loss: 1.9799
# Epoch [    3/   30] | d_loss: 0.7862 | g_loss: 1.8659
# Epoch [    3/   30] | d_loss: 0.9841 | g_loss: 1.3451
# Epoch [    3/   30] | d_loss: 0.8998 | g_loss: 1.8205
# Epoch [    3/   30] | d_loss: 0.9487 | g_loss: 2.9484
# Epoch [    3/   30] | d_loss: 0.7826 | g_loss: 1.8664
# Epoch [    3/   30] | d_loss: 0.9730 | g_loss: 1.1295
# Epoch [    3/   30] | d_loss: 0.8248 | g_loss: 2.0191
# Epoch [    3/   30] | d_loss: 0.9122 | g_loss: 1.8775
# Epoch [    3/   30] | d_loss: 0.9537 | g_loss: 1.6037
# Epoch [    3/   30] | d_loss: 0.8547 | g_loss: 1.9566
# Epoch [    3/   30] | d_loss: 0.8697 | g_loss: 1.5589
# Epoch [    3/   30] | d_loss: 1.0371 | g_loss: 1.8783
# Epoch [    3/   30] | d_loss: 1.0142 | g_loss: 1.3778
# Epoch [    3/   30] | d_loss: 0.8653 | g_loss: 1.3421
# Epoch [    3/   30] | d_loss: 1.0123 | g_loss: 2.0170
# Epoch [    4/   30] | d_loss: 0.9272 | g_loss: 1.8950
# Epoch [    4/   30] | d_loss: 1.0682 | g_loss: 2.7408
# Epoch [    4/   30] | d_loss: 0.7085 | g_loss: 2.3303
# Epoch [    4/   30] | d_loss: 0.8304 | g_loss: 2.2407
# Epoch [    4/   30] | d_loss: 0.9381 | g_loss: 2.0893
# Epoch [    4/   30] | d_loss: 0.9547 | g_loss: 1.4534
# Epoch [    4/   30] | d_loss: 0.9949 | g_loss: 1.4163
# Epoch [    4/   30] | d_loss: 1.1716 | g_loss: 1.1488
# Epoch [    4/   30] | d_loss: 0.9291 | g_loss: 1.7302
# Epoch [    4/   30] | d_loss: 0.9608 | g_loss: 2.5513
# Epoch [    4/   30] | d_loss: 1.1917 | g_loss: 2.7346
# Epoch [    4/   30] | d_loss: 1.0129 | g_loss: 1.5926
# Epoch [    4/   30] | d_loss: 0.8339 | g_loss: 2.0741
# Epoch [    4/   30] | d_loss: 0.9812 | g_loss: 2.1757
# Epoch [    4/   30] | d_loss: 0.9490 | g_loss: 1.3500
# Epoch [    5/   30] | d_loss: 1.2270 | g_loss: 2.7479
# Epoch [    5/   30] | d_loss: 1.2449 | g_loss: 1.7930
# Epoch [    5/   30] | d_loss: 0.7646 | g_loss: 1.6597
# Epoch [    5/   30] | d_loss: 0.9001 | g_loss: 1.6097
# Epoch [    5/   30] | d_loss: 0.8414 | g_loss: 1.7483
# Epoch [    5/   30] | d_loss: 1.4045 | g_loss: 2.4389
# Epoch [    5/   30] | d_loss: 0.8248 | g_loss: 1.5625
# Epoch [    5/   30] | d_loss: 1.0060 | g_loss: 2.5765
# Epoch [    5/   30] | d_loss: 0.8587 | g_loss: 2.6196
# Epoch [    5/   30] | d_loss: 0.7633 | g_loss: 1.8327
# Epoch [    5/   30] | d_loss: 1.4632 | g_loss: 1.4094
# Epoch [    5/   30] | d_loss: 0.8029 | g_loss: 2.1397
# Epoch [    5/   30] | d_loss: 0.8000 | g_loss: 1.8891
# Epoch [    5/   30] | d_loss: 0.9876 | g_loss: 1.0208
# Epoch [    5/   30] | d_loss: 0.9408 | g_loss: 2.7990
# Epoch [    6/   30] | d_loss: 1.1493 | g_loss: 1.0199
# Epoch [    6/   30] | d_loss: 0.7768 | g_loss: 2.0623
# Epoch [    6/   30] | d_loss: 0.8211 | g_loss: 1.8330
# Epoch [    6/   30] | d_loss: 0.9237 | g_loss: 1.3056
# Epoch [    6/   30] | d_loss: 0.9441 | g_loss: 1.8488
# Epoch [    6/   30] | d_loss: 0.9321 | g_loss: 1.3173
# Epoch [    6/   30] | d_loss: 1.1677 | g_loss: 3.0511
# Epoch [    6/   30] | d_loss: 1.0495 | g_loss: 2.8064
# Epoch [    6/   30] | d_loss: 1.0584 | g_loss: 2.5272
# Epoch [    6/   30] | d_loss: 0.7650 | g_loss: 1.3217
# Epoch [    6/   30] | d_loss: 1.0894 | g_loss: 2.7446
# Epoch [    6/   30] | d_loss: 0.8208 | g_loss: 1.4126
# Epoch [    6/   30] | d_loss: 0.8490 | g_loss: 1.9664
# Epoch [    6/   30] | d_loss: 0.8494 | g_loss: 1.7552
# Epoch [    6/   30] | d_loss: 0.8091 | g_loss: 1.6005
# Epoch [    7/   30] | d_loss: 1.0624 | g_loss: 2.7486
# Epoch [    7/   30] | d_loss: 0.8596 | g_loss: 2.0411
# Epoch [    7/   30] | d_loss: 0.8065 | g_loss: 1.6054
# Epoch [    7/   30] | d_loss: 0.8628 | g_loss: 2.3285
# Epoch [    7/   30] | d_loss: 0.8889 | g_loss: 1.8355
# Epoch [    7/   30] | d_loss: 0.8692 | g_loss: 1.9256
# Epoch [    7/   30] | d_loss: 0.7791 | g_loss: 1.7854
# Epoch [    7/   30] | d_loss: 0.6916 | g_loss: 2.0059
# Epoch [    7/   30] | d_loss: 0.9402 | g_loss: 2.6062
# Epoch [    7/   30] | d_loss: 0.8837 | g_loss: 1.8677
# Epoch [    7/   30] | d_loss: 0.8418 | g_loss: 1.5696
# Epoch [    7/   30] | d_loss: 0.8130 | g_loss: 1.8551
# Epoch [    7/   30] | d_loss: 0.8321 | g_loss: 1.5652
# Epoch [    7/   30] | d_loss: 0.8815 | g_loss: 1.7807
# Epoch [    7/   30] | d_loss: 0.8583 | g_loss: 1.5219
# Epoch [    8/   30] | d_loss: 0.7769 | g_loss: 1.9510
# Epoch [    8/   30] | d_loss: 0.7089 | g_loss: 1.8849
# Epoch [    8/   30] | d_loss: 0.7066 | g_loss: 1.5826
# Epoch [    8/   30] | d_loss: 0.9279 | g_loss: 1.4111
# Epoch [    8/   30] | d_loss: 0.8971 | g_loss: 2.2943
# Epoch [    8/   30] | d_loss: 0.8280 | g_loss: 1.7818
# Epoch [    8/   30] | d_loss: 1.2471 | g_loss: 2.7037
# Epoch [    8/   30] | d_loss: 0.8513 | g_loss: 1.5979
# Epoch [    8/   30] | d_loss: 0.9029 | g_loss: 1.4684
# Epoch [    8/   30] | d_loss: 1.3682 | g_loss: 2.9456
# Epoch [    8/   30] | d_loss: 0.9037 | g_loss: 1.9429
# Epoch [    8/   30] | d_loss: 1.0287 | g_loss: 2.1403
# Epoch [    8/   30] | d_loss: 0.9295 | g_loss: 1.7123
# Epoch [    8/   30] | d_loss: 0.6724 | g_loss: 1.5034
# Epoch [    8/   30] | d_loss: 0.7570 | g_loss: 1.8709
# Epoch [    9/   30] | d_loss: 1.0043 | g_loss: 3.2359
# Epoch [    9/   30] | d_loss: 0.9127 | g_loss: 0.8663
# Epoch [    9/   30] | d_loss: 0.7798 | g_loss: 2.3377
# Epoch [    9/   30] | d_loss: 0.7342 | g_loss: 2.0390
# Epoch [    9/   30] | d_loss: 0.7967 | g_loss: 1.5740
# Epoch [    9/   30] | d_loss: 0.8477 | g_loss: 2.1970
# Epoch [    9/   30] | d_loss: 0.8929 | g_loss: 1.2865
# Epoch [    9/   30] | d_loss: 1.0297 | g_loss: 0.9410
# Epoch [    9/   30] | d_loss: 0.8360 | g_loss: 2.0451
# Epoch [    9/   30] | d_loss: 0.8852 | g_loss: 1.1518
# Epoch [    9/   30] | d_loss: 0.8459 | g_loss: 2.0363
# Epoch [    9/   30] | d_loss: 0.7896 | g_loss: 1.7685
# Epoch [    9/   30] | d_loss: 2.4896 | g_loss: 0.6554
# Epoch [    9/   30] | d_loss: 0.7058 | g_loss: 2.2863
# Epoch [    9/   30] | d_loss: 1.0237 | g_loss: 2.8765
# Epoch [   10/   30] | d_loss: 0.7925 | g_loss: 1.7680
# Epoch [   10/   30] | d_loss: 0.8696 | g_loss: 1.5912
# Epoch [   10/   30] | d_loss: 0.8605 | g_loss: 1.3338
# Epoch [   10/   30] | d_loss: 1.0889 | g_loss: 2.6968
# Epoch [   10/   30] | d_loss: 0.6945 | g_loss: 1.7530
# Epoch [   10/   30] | d_loss: 0.7674 | g_loss: 1.7499
# Epoch [   10/   30] | d_loss: 0.6638 | g_loss: 2.2890
# Epoch [   10/   30] | d_loss: 0.8219 | g_loss: 1.3163
# Epoch [   10/   30] | d_loss: 0.8492 | g_loss: 1.2947
# Epoch [   10/   30] | d_loss: 0.8437 | g_loss: 1.6894
# Epoch [   10/   30] | d_loss: 0.8582 | g_loss: 2.3649
# Epoch [   10/   30] | d_loss: 0.7549 | g_loss: 1.3365
# Epoch [   10/   30] | d_loss: 0.9908 | g_loss: 1.2773
# Epoch [   10/   30] | d_loss: 0.7858 | g_loss: 2.4349
# Epoch [   10/   30] | d_loss: 0.6152 | g_loss: 2.2916
# Epoch [   11/   30] | d_loss: 0.9495 | g_loss: 2.3682
# Epoch [   11/   30] | d_loss: 0.9539 | g_loss: 1.0529
# Epoch [   11/   30] | d_loss: 0.8872 | g_loss: 1.1838
# Epoch [   11/   30] | d_loss: 1.1888 | g_loss: 2.6474
# Epoch [   11/   30] | d_loss: 0.7392 | g_loss: 1.4804
# Epoch [   11/   30] | d_loss: 1.0751 | g_loss: 2.8151
# Epoch [   11/   30] | d_loss: 1.0130 | g_loss: 2.1514
# Epoch [   11/   30] | d_loss: 0.6506 | g_loss: 1.9577
# Epoch [   11/   30] | d_loss: 0.8459 | g_loss: 1.1235
# Epoch [   11/   30] | d_loss: 0.8103 | g_loss: 2.4259
# Epoch [   11/   30] | d_loss: 0.8017 | g_loss: 1.2874
# Epoch [   11/   30] | d_loss: 1.0351 | g_loss: 2.8656
# Epoch [   11/   30] | d_loss: 0.8108 | g_loss: 1.3148
# Epoch [   11/   30] | d_loss: 0.7727 | g_loss: 2.1358
# Epoch [   11/   30] | d_loss: 0.7347 | g_loss: 1.7522
# Epoch [   12/   30] | d_loss: 0.7970 | g_loss: 2.2377
# Epoch [   12/   30] | d_loss: 0.7309 | g_loss: 1.6152
# Epoch [   12/   30] | d_loss: 0.6417 | g_loss: 2.3451
# Epoch [   12/   30] | d_loss: 0.6670 | g_loss: 1.6944
# Epoch [   12/   30] | d_loss: 0.9056 | g_loss: 2.6237
# Epoch [   12/   30] | d_loss: 1.0714 | g_loss: 3.1169
# Epoch [   12/   30] | d_loss: 0.6717 | g_loss: 2.0544
# Epoch [   12/   30] | d_loss: 0.8108 | g_loss: 1.0589
# Epoch [   12/   30] | d_loss: 0.8636 | g_loss: 1.6943
# Epoch [   12/   30] | d_loss: 0.6403 | g_loss: 1.8212
# Epoch [   12/   30] | d_loss: 0.8552 | g_loss: 3.3273
# Epoch [   12/   30] | d_loss: 0.7993 | g_loss: 3.5292
# Epoch [   12/   30] | d_loss: 0.7185 | g_loss: 2.5527
# Epoch [   12/   30] | d_loss: 0.8873 | g_loss: 1.7584
# Epoch [   12/   30] | d_loss: 0.7838 | g_loss: 2.5246
# Epoch [   13/   30] | d_loss: 0.7586 | g_loss: 1.3438
# Epoch [   13/   30] | d_loss: 0.6337 | g_loss: 1.6948
# Epoch [   13/   30] | d_loss: 0.6340 | g_loss: 2.3567
# Epoch [   13/   30] | d_loss: 0.6628 | g_loss: 1.5163
# Epoch [   13/   30] | d_loss: 0.9183 | g_loss: 2.6080
# Epoch [   13/   30] | d_loss: 0.7356 | g_loss: 1.9409
# Epoch [   13/   30] | d_loss: 0.7202 | g_loss: 1.3519
# Epoch [   13/   30] | d_loss: 0.7868 | g_loss: 2.0732
# Epoch [   13/   30] | d_loss: 0.6622 | g_loss: 2.1660
# Epoch [   13/   30] | d_loss: 0.6289 | g_loss: 2.6775
# Epoch [   13/   30] | d_loss: 0.6545 | g_loss: 2.2643
# Epoch [   13/   30] | d_loss: 0.9100 | g_loss: 2.8278
# Epoch [   13/   30] | d_loss: 0.7976 | g_loss: 1.9874
# Epoch [   13/   30] | d_loss: 0.9798 | g_loss: 3.0857
# Epoch [   13/   30] | d_loss: 0.8534 | g_loss: 1.7461
# Epoch [   14/   30] | d_loss: 0.9120 | g_loss: 3.7189
# Epoch [   14/   30] | d_loss: 1.3710 | g_loss: 2.6001
# Epoch [   14/   30] | d_loss: 0.7683 | g_loss: 2.0642
# Epoch [   14/   30] | d_loss: 0.5963 | g_loss: 2.6085
# Epoch [   14/   30] | d_loss: 0.6893 | g_loss: 1.8022
# Epoch [   14/   30] | d_loss: 0.7795 | g_loss: 3.0387
# Epoch [   14/   30] | d_loss: 0.6962 | g_loss: 2.9692
# Epoch [   14/   30] | d_loss: 0.6412 | g_loss: 2.9011
# Epoch [   14/   30] | d_loss: 0.5632 | g_loss: 2.1133
# Epoch [   14/   30] | d_loss: 0.7100 | g_loss: 2.7560
# Epoch [   14/   30] | d_loss: 0.6578 | g_loss: 2.0059
# Epoch [   14/   30] | d_loss: 1.6467 | g_loss: 0.7390
# Epoch [   14/   30] | d_loss: 0.6799 | g_loss: 2.9266
# Epoch [   14/   30] | d_loss: 1.0916 | g_loss: 2.6559
# Epoch [   14/   30] | d_loss: 0.8545 | g_loss: 3.6763
# Epoch [   15/   30] | d_loss: 0.6284 | g_loss: 3.3920
# Epoch [   15/   30] | d_loss: 0.6844 | g_loss: 2.0350
# Epoch [   15/   30] | d_loss: 0.6631 | g_loss: 2.1706
# Epoch [   15/   30] | d_loss: 0.6292 | g_loss: 2.3798
# Epoch [   15/   30] | d_loss: 1.2304 | g_loss: 3.5068
# Epoch [   15/   30] | d_loss: 0.9094 | g_loss: 3.0906
# Epoch [   15/   30] | d_loss: 0.9045 | g_loss: 2.2798
# Epoch [   15/   30] | d_loss: 0.6731 | g_loss: 2.0617
# Epoch [   15/   30] | d_loss: 0.6715 | g_loss: 2.4294
# Epoch [   15/   30] | d_loss: 0.5674 | g_loss: 2.8491
# Epoch [   15/   30] | d_loss: 0.7665 | g_loss: 2.0634
# Epoch [   15/   30] | d_loss: 0.6326 | g_loss: 2.9778
# Epoch [   15/   30] | d_loss: 0.7229 | g_loss: 2.2166
# Epoch [   15/   30] | d_loss: 0.6409 | g_loss: 2.3424
# Epoch [   15/   30] | d_loss: 0.7879 | g_loss: 1.9650
# Epoch [   16/   30] | d_loss: 0.6349 | g_loss: 1.7828
# Epoch [   16/   30] | d_loss: 0.9186 | g_loss: 1.5408
# Epoch [   16/   30] | d_loss: 0.5546 | g_loss: 2.4171
# Epoch [   16/   30] | d_loss: 0.8864 | g_loss: 3.3624
# Epoch [   16/   30] | d_loss: 0.6420 | g_loss: 1.6544
# Epoch [   16/   30] | d_loss: 0.7042 | g_loss: 1.1978
# Epoch [   16/   30] | d_loss: 0.6676 | g_loss: 2.4855
# Epoch [   16/   30] | d_loss: 0.5899 | g_loss: 2.8967
# Epoch [   16/   30] | d_loss: 0.6825 | g_loss: 1.8870
# Epoch [   16/   30] | d_loss: 0.6688 | g_loss: 3.5299
# Epoch [   16/   30] | d_loss: 0.6429 | g_loss: 2.4169
# Epoch [   16/   30] | d_loss: 0.7046 | g_loss: 2.4771
# Epoch [   16/   30] | d_loss: 0.8076 | g_loss: 2.3793
# Epoch [   16/   30] | d_loss: 0.9330 | g_loss: 1.1800
# Epoch [   16/   30] | d_loss: 0.8698 | g_loss: 2.1206
# Epoch [   17/   30] | d_loss: 1.0399 | g_loss: 4.4549
# Epoch [   17/   30] | d_loss: 0.7412 | g_loss: 1.9157
# Epoch [   17/   30] | d_loss: 0.8098 | g_loss: 2.2253
# Epoch [   17/   30] | d_loss: 0.6605 | g_loss: 2.2524
# Epoch [   17/   30] | d_loss: 0.5641 | g_loss: 2.8381
# Epoch [   17/   30] | d_loss: 0.8289 | g_loss: 3.3057
# Epoch [   17/   30] | d_loss: 0.7139 | g_loss: 2.4879
# Epoch [   17/   30] | d_loss: 0.5911 | g_loss: 2.3827
# Epoch [   17/   30] | d_loss: 0.6597 | g_loss: 2.4889
# Epoch [   17/   30] | d_loss: 0.6049 | g_loss: 3.1671
# Epoch [   17/   30] | d_loss: 0.7137 | g_loss: 2.3374
# Epoch [   17/   30] | d_loss: 1.0302 | g_loss: 1.2232
# Epoch [   17/   30] | d_loss: 0.7333 | g_loss: 2.3161
# Epoch [   17/   30] | d_loss: 0.6059 | g_loss: 3.0403
# Epoch [   17/   30] | d_loss: 0.5836 | g_loss: 2.2960
# Epoch [   18/   30] | d_loss: 0.7708 | g_loss: 2.2257
# Epoch [   18/   30] | d_loss: 0.8339 | g_loss: 3.6761
# Epoch [   18/   30] | d_loss: 0.5935 | g_loss: 1.9903
# Epoch [   18/   30] | d_loss: 0.6894 | g_loss: 2.4651
# Epoch [   18/   30] | d_loss: 1.4101 | g_loss: 1.1270
# Epoch [   18/   30] | d_loss: 0.5886 | g_loss: 2.9903
# Epoch [   18/   30] | d_loss: 0.6486 | g_loss: 2.6073
# Epoch [   18/   30] | d_loss: 0.7115 | g_loss: 1.4658
# Epoch [   18/   30] | d_loss: 0.7786 | g_loss: 1.8396
# Epoch [   18/   30] | d_loss: 0.6911 | g_loss: 2.8177
# Epoch [   18/   30] | d_loss: 0.5375 | g_loss: 2.6937
# Epoch [   18/   30] | d_loss: 0.6037 | g_loss: 2.4500
# Epoch [   18/   30] | d_loss: 0.8086 | g_loss: 2.6713
# Epoch [   18/   30] | d_loss: 0.5858 | g_loss: 3.0646
# Epoch [   18/   30] | d_loss: 0.5178 | g_loss: 2.6377
# Epoch [   19/   30] | d_loss: 0.5811 | g_loss: 2.0955
# Epoch [   19/   30] | d_loss: 0.5848 | g_loss: 2.8692
# Epoch [   19/   30] | d_loss: 0.7233 | g_loss: 2.2261
# Epoch [   19/   30] | d_loss: 0.5504 | g_loss: 2.5471
# Epoch [   19/   30] | d_loss: 0.8982 | g_loss: 1.2669
# Epoch [   19/   30] | d_loss: 0.7655 | g_loss: 2.8429
# Epoch [   19/   30] | d_loss: 0.6016 | g_loss: 2.6424
# Epoch [   19/   30] | d_loss: 0.5242 | g_loss: 2.9419
# Epoch [   19/   30] | d_loss: 0.5412 | g_loss: 2.2437
# Epoch [   19/   30] | d_loss: 0.5989 | g_loss: 2.1101
# Epoch [   19/   30] | d_loss: 0.9471 | g_loss: 1.6862
# Epoch [   19/   30] | d_loss: 0.7240 | g_loss: 2.9981
# Epoch [   19/   30] | d_loss: 0.5892 | g_loss: 1.5028
# Epoch [   19/   30] | d_loss: 0.5711 | g_loss: 2.9245
# Epoch [   19/   30] | d_loss: 0.5400 | g_loss: 2.3267
# Epoch [   20/   30] | d_loss: 0.5661 | g_loss: 2.3956
# Epoch [   20/   30] | d_loss: 0.6145 | g_loss: 2.5040
# Epoch [   20/   30] | d_loss: 0.7368 | g_loss: 2.7981
# Epoch [   20/   30] | d_loss: 0.7034 | g_loss: 2.0882
# Epoch [   20/   30] | d_loss: 0.6813 | g_loss: 1.8852
# Epoch [   20/   30] | d_loss: 0.5665 | g_loss: 2.0812
# Epoch [   20/   30] | d_loss: 0.7030 | g_loss: 1.2988
# Epoch [   20/   30] | d_loss: 0.5305 | g_loss: 2.2483
# Epoch [   20/   30] | d_loss: 0.7152 | g_loss: 1.1881
# Epoch [   20/   30] | d_loss: 0.6574 | g_loss: 3.2773
# Epoch [   20/   30] | d_loss: 0.5025 | g_loss: 2.9715
# Epoch [   20/   30] | d_loss: 0.6086 | g_loss: 3.2102
# Epoch [   20/   30] | d_loss: 0.5594 | g_loss: 3.0583
# Epoch [   20/   30] | d_loss: 0.5949 | g_loss: 1.8439
# Epoch [   20/   30] | d_loss: 0.6230 | g_loss: 4.1899
# Epoch [   21/   30] | d_loss: 0.6328 | g_loss: 1.9894
# Epoch [   21/   30] | d_loss: 0.5615 | g_loss: 2.2232
# Epoch [   21/   30] | d_loss: 0.6293 | g_loss: 1.9762
# Epoch [   21/   30] | d_loss: 0.5438 | g_loss: 2.6030
# Epoch [   21/   30] | d_loss: 0.6269 | g_loss: 1.6030
# Epoch [   21/   30] | d_loss: 0.8169 | g_loss: 1.7484
# Epoch [   21/   30] | d_loss: 0.5514 | g_loss: 2.4818
# Epoch [   21/   30] | d_loss: 0.5610 | g_loss: 1.9281
# Epoch [   21/   30] | d_loss: 0.5004 | g_loss: 2.6227
# Epoch [   21/   30] | d_loss: 0.9810 | g_loss: 1.7626
# Epoch [   21/   30] | d_loss: 0.6339 | g_loss: 1.8555
# Epoch [   21/   30] | d_loss: 1.0389 | g_loss: 4.2325
# Epoch [   21/   30] | d_loss: 1.1287 | g_loss: 3.6548
# Epoch [   21/   30] | d_loss: 0.6361 | g_loss: 3.0740
# Epoch [   21/   30] | d_loss: 0.5729 | g_loss: 2.6901
# Epoch [   22/   30] | d_loss: 0.5756 | g_loss: 2.2142
# Epoch [   22/   30] | d_loss: 0.5071 | g_loss: 2.9410
# Epoch [   22/   30] | d_loss: 0.4732 | g_loss: 3.5421
# Epoch [   22/   30] | d_loss: 0.4596 | g_loss: 2.6522
# Epoch [   22/   30] | d_loss: 0.6239 | g_loss: 2.6735
# Epoch [   22/   30] | d_loss: 0.7504 | g_loss: 3.5420
# Epoch [   22/   30] | d_loss: 0.5654 | g_loss: 2.5050
# Epoch [   22/   30] | d_loss: 0.7100 | g_loss: 3.1808
# Epoch [   22/   30] | d_loss: 0.7764 | g_loss: 3.6488
# Epoch [   22/   30] | d_loss: 1.2280 | g_loss: 0.7685
# Epoch [   22/   30] | d_loss: 0.5937 | g_loss: 1.7185
# Epoch [   22/   30] | d_loss: 0.5116 | g_loss: 2.9208
# Epoch [   22/   30] | d_loss: 0.4276 | g_loss: 3.8285
# Epoch [   22/   30] | d_loss: 0.5514 | g_loss: 3.3566
# Epoch [   22/   30] | d_loss: 0.4950 | g_loss: 2.5979
# Epoch [   23/   30] | d_loss: 0.6142 | g_loss: 2.3127
# Epoch [   23/   30] | d_loss: 0.6413 | g_loss: 2.4638
# Epoch [   23/   30] | d_loss: 0.5862 | g_loss: 2.2142
# Epoch [   23/   30] | d_loss: 0.8189 | g_loss: 2.7297
# Epoch [   23/   30] | d_loss: 0.6023 | g_loss: 2.4151
# Epoch [   23/   30] | d_loss: 0.7343 | g_loss: 1.3990
# Epoch [   23/   30] | d_loss: 0.5108 | g_loss: 2.5154
# Epoch [   23/   30] | d_loss: 0.5482 | g_loss: 1.9264
# Epoch [   23/   30] | d_loss: 0.4778 | g_loss: 2.3019
# Epoch [   23/   30] | d_loss: 0.6484 | g_loss: 2.5282
# Epoch [   23/   30] | d_loss: 0.5723 | g_loss: 3.6754
# Epoch [   23/   30] | d_loss: 0.7764 | g_loss: 1.6959
# Epoch [   23/   30] | d_loss: 0.5576 | g_loss: 2.1414
# Epoch [   23/   30] | d_loss: 1.0123 | g_loss: 1.7930
# Epoch [   23/   30] | d_loss: 0.6269 | g_loss: 1.6045
# Epoch [   24/   30] | d_loss: 0.6878 | g_loss: 2.6020
# Epoch [   24/   30] | d_loss: 0.5803 | g_loss: 2.3355
# Epoch [   24/   30] | d_loss: 0.5855 | g_loss: 2.6274
# Epoch [   24/   30] | d_loss: 0.8203 | g_loss: 1.8011
# Epoch [   24/   30] | d_loss: 0.5324 | g_loss: 2.4505
# Epoch [   24/   30] | d_loss: 0.6909 | g_loss: 1.6655
# Epoch [   24/   30] | d_loss: 1.0307 | g_loss: 1.1896
# Epoch [   24/   30] | d_loss: 0.6074 | g_loss: 2.5771
# Epoch [   24/   30] | d_loss: 1.0630 | g_loss: 3.9171
# Epoch [   24/   30] | d_loss: 0.5598 | g_loss: 2.1124
# Epoch [   24/   30] | d_loss: 0.7022 | g_loss: 2.2374
# Epoch [   24/   30] | d_loss: 0.6119 | g_loss: 3.1857
# Epoch [   24/   30] | d_loss: 0.5126 | g_loss: 2.8577
# Epoch [   24/   30] | d_loss: 0.5008 | g_loss: 2.9820
# Epoch [   24/   30] | d_loss: 0.5275 | g_loss: 3.5092
# Epoch [   25/   30] | d_loss: 0.7691 | g_loss: 3.1362
# Epoch [   25/   30] | d_loss: 0.7810 | g_loss: 4.2421
# Epoch [   25/   30] | d_loss: 0.5179 | g_loss: 2.8828
# Epoch [   25/   30] | d_loss: 0.6147 | g_loss: 3.5027
# Epoch [   25/   30] | d_loss: 0.6306 | g_loss: 3.1663
# Epoch [   25/   30] | d_loss: 0.5446 | g_loss: 1.9220
# Epoch [   25/   30] | d_loss: 0.6379 | g_loss: 2.7881
# Epoch [   25/   30] | d_loss: 1.4901 | g_loss: 1.8710
# Epoch [   25/   30] | d_loss: 0.6182 | g_loss: 1.8041
# Epoch [   25/   30] | d_loss: 0.4600 | g_loss: 2.7940
# Epoch [   25/   30] | d_loss: 0.6573 | g_loss: 1.4709
# Epoch [   25/   30] | d_loss: 0.6169 | g_loss: 3.2043
# Epoch [   25/   30] | d_loss: 0.7687 | g_loss: 3.6442
# Epoch [   25/   30] | d_loss: 0.4821 | g_loss: 2.2479
# Epoch [   25/   30] | d_loss: 0.6000 | g_loss: 2.0392
# Epoch [   26/   30] | d_loss: 0.4757 | g_loss: 2.5849
# Epoch [   26/   30] | d_loss: 0.4082 | g_loss: 3.2112
# Epoch [   26/   30] | d_loss: 0.6326 | g_loss: 1.8221
# Epoch [   26/   30] | d_loss: 0.6244 | g_loss: 0.9937
# Epoch [   26/   30] | d_loss: 0.4696 | g_loss: 2.4792
# Epoch [   26/   30] | d_loss: 0.4228 | g_loss: 2.9991
# Epoch [   26/   30] | d_loss: 0.4468 | g_loss: 3.4599
# Epoch [   26/   30] | d_loss: 0.4303 | g_loss: 2.6097
# Epoch [   26/   30] | d_loss: 0.6219 | g_loss: 2.9416
# Epoch [   26/   30] | d_loss: 0.5417 | g_loss: 2.5908
# Epoch [   26/   30] | d_loss: 0.5546 | g_loss: 1.8355
# Epoch [   26/   30] | d_loss: 0.5444 | g_loss: 3.1593
# Epoch [   26/   30] | d_loss: 1.0500 | g_loss: 3.8306
# Epoch [   26/   30] | d_loss: 0.7280 | g_loss: 1.1293
# Epoch [   26/   30] | d_loss: 0.5370 | g_loss: 2.4255
# Epoch [   27/   30] | d_loss: 0.4355 | g_loss: 3.3663
# Epoch [   27/   30] | d_loss: 0.5445 | g_loss: 3.6543
# Epoch [   27/   30] | d_loss: 0.8545 | g_loss: 1.8968
# Epoch [   27/   30] | d_loss: 0.4171 | g_loss: 3.7662
# Epoch [   27/   30] | d_loss: 0.4522 | g_loss: 3.1420
# Epoch [   27/   30] | d_loss: 0.5135 | g_loss: 2.3230
# Epoch [   27/   30] | d_loss: 0.5438 | g_loss: 2.3845
# Epoch [   27/   30] | d_loss: 0.4945 | g_loss: 1.7982
# Epoch [   27/   30] | d_loss: 0.5183 | g_loss: 3.0826
# Epoch [   27/   30] | d_loss: 0.5586 | g_loss: 1.6625
# Epoch [   27/   30] | d_loss: 0.4969 | g_loss: 3.6538
# Epoch [   27/   30] | d_loss: 0.6496 | g_loss: 1.8484
# Epoch [   27/   30] | d_loss: 0.6073 | g_loss: 1.7902
# Epoch [   27/   30] | d_loss: 0.6758 | g_loss: 3.0315
# Epoch [   27/   30] | d_loss: 0.6366 | g_loss: 4.2679
# Epoch [   28/   30] | d_loss: 1.6028 | g_loss: 0.4581
# Epoch [   28/   30] | d_loss: 0.6866 | g_loss: 3.2473
# Epoch [   28/   30] | d_loss: 0.7316 | g_loss: 2.9197
# Epoch [   28/   30] | d_loss: 0.6424 | g_loss: 2.3497
# Epoch [   28/   30] | d_loss: 0.5977 | g_loss: 3.0374
# Epoch [   28/   30] | d_loss: 0.5049 | g_loss: 3.5053
# Epoch [   28/   30] | d_loss: 0.8768 | g_loss: 4.0769
# Epoch [   28/   30] | d_loss: 0.5794 | g_loss: 3.3458
# Epoch [   28/   30] | d_loss: 0.5628 | g_loss: 1.8507
# Epoch [   28/   30] | d_loss: 0.5352 | g_loss: 3.2805
# Epoch [   28/   30] | d_loss: 0.5741 | g_loss: 2.2430
# Epoch [   28/   30] | d_loss: 0.5996 | g_loss: 3.5877
# Epoch [   28/   30] | d_loss: 0.4945 | g_loss: 3.3311
# Epoch [   28/   30] | d_loss: 0.6448 | g_loss: 2.6645
# Epoch [   28/   30] | d_loss: 0.8945 | g_loss: 1.5293
# Epoch [   29/   30] | d_loss: 0.5216 | g_loss: 2.4411
# Epoch [   29/   30] | d_loss: 0.6347 | g_loss: 3.1348
# Epoch [   29/   30] | d_loss: 0.6721 | g_loss: 2.1139
# Epoch [   29/   30] | d_loss: 0.4711 | g_loss: 3.5184
# Epoch [   29/   30] | d_loss: 0.5195 | g_loss: 3.2447
# Epoch [   29/   30] | d_loss: 0.8854 | g_loss: 3.4776
# Epoch [   29/   30] | d_loss: 0.7155 | g_loss: 2.1610
# Epoch [   29/   30] | d_loss: 0.8179 | g_loss: 1.6806
# Epoch [   29/   30] | d_loss: 0.4863 | g_loss: 2.4972
# Epoch [   29/   30] | d_loss: 0.4428 | g_loss: 2.7129
# Epoch [   29/   30] | d_loss: 0.5271 | g_loss: 1.5347
# Epoch [   29/   30] | d_loss: 0.5159 | g_loss: 2.4143
# Epoch [   29/   30] | d_loss: 0.5309 | g_loss: 2.3564
# Epoch [   29/   30] | d_loss: 0.9623 | g_loss: 1.7334
# Epoch [   29/   30] | d_loss: 0.6116 | g_loss: 2.9077
# Epoch [   30/   30] | d_loss: 0.4657 | g_loss: 3.1405
# Epoch [   30/   30] | d_loss: 0.5154 | g_loss: 3.3357
# Epoch [   30/   30] | d_loss: 0.5492 | g_loss: 3.8180
# Epoch [   30/   30] | d_loss: 0.4444 | g_loss: 2.9530
# Epoch [   30/   30] | d_loss: 0.6644 | g_loss: 3.1400
# Epoch [   30/   30] | d_loss: 0.4575 | g_loss: 3.0252
# Epoch [   30/   30] | d_loss: 0.4171 | g_loss: 4.0536
# Epoch [   30/   30] | d_loss: 0.7411 | g_loss: 3.7393
# Epoch [   30/   30] | d_loss: 0.5810 | g_loss: 2.2347
# Epoch [   30/   30] | d_loss: 0.5504 | g_loss: 3.0979
# Epoch [   30/   30] | d_loss: 0.6306 | g_loss: 1.6057
# Epoch [   30/   30] | d_loss: 0.8912 | g_loss: 4.3771
# Epoch [   30/   30] | d_loss: 0.5487 | g_loss: 3.1686
# Epoch [   30/   30] | d_loss: 0.5626 | g_loss: 3.0148
# Epoch [   30/   30] | d_loss: 0.6039 | g_loss: 2.4747

# %% [markdown]
# ## Training loss
#
# Plot the training losses for the generator and discriminator, recorded after each epoch.

# %%
fig, ax = plt.subplots()
losses = np.array(losses)
plt.plot(losses.T[0], label='Discriminator', alpha=0.5)
plt.plot(losses.T[1], label='Generator', alpha=0.5)
plt.title("Training Losses")
plt.legend()

# %% [markdown]
# ## Generator samples from training
#
# View samples of images from the generator, and answer a question about the strengths and weaknesses of your trained models.

# %%
# helper function for viewing a list of passed in sample images
def view_samples(epoch, samples):
    fig, axes = plt.subplots(figsize=(16,4), nrows=2, ncols=8, sharey=True, sharex=True)
    for ax, img in zip(axes.flatten(), samples[epoch]):
        img = img.detach().cpu().numpy()
        img = np.transpose(img, (1, 2, 0))
        img = ((img + 1)*255 / (2)).astype(np.uint8)
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
        im = ax.imshow(img.reshape((32,32,3)))

# %%
# Load samples from generator, taken while training
with open('train_samples.pkl', 'rb') as f:
    samples = pkl.load(f)

# %%
_ = view_samples(-1, samples)

# %% [markdown]
# ### Question: What do you notice about your generated samples and how might you improve this model?
# When you answer this question, consider the following factors:
# * The dataset is biased; it is made of "celebrity" faces that are mostly white
# * Model size; larger models have the opportunity to learn more features in a data feature space
# * Optimization strategy; optimizers and number of epochs affect your final result

# %% [markdown]
# **Answer:**
#
# - The model generated faces that are mostly white probably hence to our dataset. The data set mostly were of western celebrities, therefore our generator did not learn certain features of different races. However, we can see that it did learn to generate people with glasses.
#
# - This model contained 4 convolutional layers for the discriminator and 4 transpose convolutional layers for the generator. The `conv_dim` was set to `32` for both the discriminator and generator. Besides that, for the calculation of the `real loss`, labels were multiplied by a constant value close to one - `0.9`. I believe, in order to accomplish better results and allow the generator to learn more sophisticated features of a human face, I could have used a model with higher dimensions or depth. Perpahps, with even more convolutional layers.
#
# - Both, the discriminator and generator, used Adam's optimizer. As well, both optimizers used the same hyperparameters `learning rate` of `0.0002`, and `betas` of `0.5` and `0.999`, which were recommended in the previous lessons. The model was run for `30` epochs in total. As the `training loss` graph indicates, the training loss for the generator was jumping up and down and at the end even got higher than it was in the middle of the training. However, we can see, that the discriminator loss showed a downward trend. I assume, training the GANs for more epochs would have increased its performance and produced better end results.

# %% [markdown]
# ### Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_face_generation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "problem_unittests.py" files in your submission.
